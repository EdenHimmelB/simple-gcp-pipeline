# %%
import os
import requests
from concurrent.futures import ThreadPoolExecutor
from datetime import datetime, timedelta

start = datetime(2024, 1, 1)
end = datetime.today()

# Create a list of dates
date_list = []
current_date = start

while current_date <= end:
    date_list.append(current_date)
    current_date += timedelta(days=1)

url_list = [
    f"""https://dumps.wikimedia.org/enwiki/{date.strftime("%Y%m%d")}/dumpstatus.json"""
    for date in date_list
]

if not os.path.exists("enwiki_dumpstatus_metadata"):
    os.makedirs("enwiki_dumpstatus_metadata")


def download_metadata(url: str):
    url_stub = url.split("/")
    file_name = os.path.join(
        "enwiki_dumpstatus_metadata", f"{url_stub[-3]}_{url_stub[-2]}_{url_stub[-1]}"
    )
    headers = {"User-Agent": "SimpleGetMetadataBot/0.0"}
    response = requests.get(url, headers=headers, stream=True)
    if response.status_code == 404:
        pass
    else:
        with open(file_name, "wb") as file:
            for chunk in response.iter_content(chunk_size=8192):
                file.write(chunk)


with ThreadPoolExecutor(max_workers=12) as executor:
    futures = [executor.submit(download_metadata, url) for url in url_list]
    for future in futures:
        future.result()

# %%
with open("enwiki_dumpstatus_metadata.json", "w") as write_file:
    for i in os.listdir("enwiki_dumpstatus_metadata"):
        with open(os.path.join("enwiki_dumpstatus_metadata", i), "r") as read_file:
            write_file.write(read_file.read())

# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
from pyspark.sql.types import (
    StructField,
    StructType,
    IntegerType,
    FloatType,
    StringType,
    ArrayType,
    MapType,
)

spark = SparkSession.builder.master("local[*]").getOrCreate()

ndjson_path = "data/enwiki_dumpstatus_metadata.json"
df = spark.read.option("multiline", "true").text(ndjson_path)
# Out:
# your 131072x1 screen size is bogus. expect trouble
# 24/09/30 02:57:00 WARN Utils: Your hostname, EdenHimmel1316 resolves to a loopback address: 127.0.1.1; using 172.25.138.88 instead (on interface eth0)
# 24/09/30 02:57:00 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/09/30 02:57:00 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df.show()
# Out:
# +--------------------+
# |               value|
# +--------------------+
# |{"jobs": {"xmlstu...|
# |{"jobs": {"xmlstu...|
# |{"jobs": {"xmlstu...|
# |{"jobs": {"xmlstu...|
# |{"jobs": {"xmlstu...|
# |{"jobs": {"xmlstu...|
# |{"jobs": {"xmlstu...|
# +--------------------+

# %%
df1 = df.select(
    F.monotonically_increasing_id().alias("id"),
    F.from_json(
        "value",
        schema=MapType(StringType(), StringType())
    ).alias("col")
)

# %%
df1.show()
# Out:
# +---+--------------------+
# | id|                 col|
# +---+--------------------+
# |  0|{jobs -> {"xmlstu...|
# |  1|{jobs -> {"xmlstu...|
# |  2|{jobs -> {"xmlstu...|
# |  3|{jobs -> {"xmlstu...|
# |  4|{jobs -> {"xmlstu...|
# |  5|{jobs -> {"xmlstu...|
# |  6|{jobs -> {"xmlstu...|
# +---+--------------------+

# %%
df1 = df1.select("id", F.explode_outer("col"))

# %%
df1.show()
# Out:
# +---+-------+--------------------+
# | id|    key|               value|
# +---+-------+--------------------+
# |  0|   jobs|{"xmlstubsdumprec...|
# |  0|version|                 0.8|
# |  1|   jobs|{"xmlstubsdumprec...|
# |  1|version|                 0.8|
# |  2|   jobs|{"xmlstubsdumprec...|
# |  2|version|                 0.8|
# |  3|   jobs|{"xmlstubsdumprec...|
# |  3|version|                 0.8|
# |  4|   jobs|{"xmlstubsdumprec...|
# |  4|version|                 0.8|
# |  5|   jobs|{"xmlstubsdumprec...|
# |  5|version|                 0.8|
# |  6|   jobs|{"xmlstubsdumprec...|
# |  6|version|                 0.8|
# +---+-------+--------------------+

# %%
pivot_df1 = df1.groupBy("id").pivot("key").agg(F.first("value"))

# %%
pivot_df1.show()
# Out:
# +---+--------------------+-------+
# | id|                jobs|version|
# +---+--------------------+-------+
# |  0|{"xmlstubsdumprec...|    0.8|
# |  1|{"xmlstubsdumprec...|    0.8|
# |  2|{"xmlstubsdumprec...|    0.8|
# |  3|{"xmlstubsdumprec...|    0.8|
# |  4|{"xmlstubsdumprec...|    0.8|
# |  5|{"xmlstubsdumprec...|    0.8|
# |  6|{"xmlstubsdumprec...|    0.8|
# +---+--------------------+-------+

# %%
df2 = pivot_df1.select(
    "id",
    "version",
    F.from_json("jobs", schema=MapType(StringType(), StringType())).alias("col"),
)

pivot_df2 = (
    df2.select("id", "version", F.explode_outer("col").alias("dump_group", "dump_info"))
)

# df4 = df3.select("id", F.explode_outer("col")).groupBy("id").pivot("key").agg(F.rtrim(F.first("value")))

# %%
pivot_df2.show(truncate=False)
# Out:
# +---+-------+------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |id |version|dump_group              |dump_info                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# +---+-------+------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |0  |0.8    |xmlstubsdumprecombine   |{"status":"done","updated":"2024-07-22 09:14:34","files":{"enwiki-20240720-stub-meta-history.xml.gz":{"size":104302861395,"url":"/enwiki/20240720/enwiki-20240720-stub-meta-history.xml.gz","md5":"9660478d737bbed6c5fbf4a61a979dc9","sha1":"260abb9fee17964ac9e35127cbd7307e876a7a8c"},"enwiki-20240720-stub-meta-current.xml.gz":{"size":6788744833,"url":"/enwiki/20240720/enwiki-20240720-stub-meta-current.xml.gz","md5":"44927d4de920f4b7efc13a5178074cf2","sha1":"8ca2e2a7225560a5b49eac1507d306a1bcb7d76a"},"enwiki-20240720-stub-articles.xml.gz":{"size":2902815267,"url":"/enwiki/20240720/enwiki-20240720-stub-articles.xml.gz","md5":"1268303e60662a55675cf6cb2f6216e1","sha1":"54bb1cf2da0872bc6af5d3e6e90a7a9d35e3a25a"}}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# |0  |0.8    |xmlstubsdump            |{"status":"done","updated":"2024-07-22 07:45:07","files":{"enwiki-20240720-stub-meta-history1.xml.gz":{"size":3460679990,"url":"/enwiki/20240720/enwiki-20240720-stub-meta-history1.xml.gz","md5":"b1ca30796f5f1d9bc1369a356b37b4fc","sha1":"568361252df89b72bb3f7c50b273eb6399a1a978"},"enwiki-20240720-stub-meta-history2.xml.gz":{"size":3665125664,"url":"/enwiki/20240720/enwiki-20240720-stub-meta-history2.xml.gz","md5":"0b9c9f24610955c23b9012e5aab06b8e","sha1":"f79e5800554a599ebec4a88e7893ee162fc06b8a"},"enwiki-20240720-stub-meta-history3.xml.gz":{"size":3665924384,"url":"/enwiki/20240720/enwiki-20240720-stub-meta-history3.xml.gz","md5":"c1307b137f16c73b0f0f923b439fa3a1","sha1":"3c748cfaa70fc146a8d1e34903b9563f30b68415"},"enwiki-20240720-stub-meta-history4.xml.gz":{"size":3706533685,"url":"/enwiki/20240720/enwiki-20240720-stub-meta-
}}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# |0  |0.8    |userformergroupstable   |{"status":"done","updated":"2024-07-20 09:46:43","files":{"enwiki-20240720-user_former_groups.sql.gz":{"size":84322,"url":"/enwiki/20240720/enwiki-20240720-user_former_groups.sql.gz","md5":"8ddbd5c19e92675bff67e4ed5b85a192","sha1":"9293f61fabebb17030ffb0e0b5284c5e42d4909a"}}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# |0  |0.8    |templatelinkstable      |{"status":"done","updated":"2024-07-20 09:22:44","files":{"enwiki-20240720-templatelinks.sql.gz":{"size":3994212010,"url":"/enwiki/20240720/enwiki-20240720-templatelinks.sql.gz","md5":"f3adfff7d2ca822ea39937dc687296d3","sha1":"c7ee9e209217725ad069bb25743655d86d23ebe8"}}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# ...
# |0  |0.8    |namespaces              |{"status":"done","updated":"2024-07-22 18:25:17","files":{"enwiki-20240720-siteinfo-namespaces.json.gz":{"size":4854,"url":"/enwiki/20240720/enwiki-20240720-siteinfo-namespaces.json.gz","md5":"40d57dd405e93d2332b6c2b441e4fe26","sha1":"0177fa3415d500c736723953f63d5f4c115484db"}}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# |0  |0.8    |metahistorybz2dump      |{"status":"skipped","updated":"2024-07-22 18:13:14"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# +---+-------+------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 20 rows

# %%
import ast
from pyspark.sql.functions import udf

@udf(MapType(StringType(), StringType()))
def parse_line(line):
    data = ast.literal_eval(line)
    return data

# %%
df3 = (
    (
        pivot_df2.select(
            "id",
            "version",
            "dump_group",
            F.explode(
                F.from_json(
                    "dump_info", schema=MapType(StringType(), StringType())
                ).alias("dump_info")
            ),
        )
    )
    .groupBy("id", "version", "dump_group")
    
    .pivot("key")
    .agg(F.trim(F.first("value")))
).drop("id")

# %%
df3.show()
# Out:
# +-------+--------------------+--------------------+------+-------------------+
# |version|          dump_group|               files|status|            updated|
# +-------+--------------------+--------------------+------+-------------------+
# |    0.8|       abstractsdump|{"enwiki-20240720...|  done|2024-07-23 05:29:01|
# |    0.8|abstractsdumpreco...|{"enwiki-20240720...|  done|2024-07-23 05:29:57|
# |    0.8|   allpagetitlesdump|{"enwiki-20240720...|  done|2024-07-22 18:28:43|
# |    0.8|        articlesdump|{"enwiki-20240720...|  done|2024-07-22 10:50:58|
# |    0.8|articlesdumprecom...|{"enwiki-20240720...|  done|2024-07-22 12:24:48|
# |    0.8|articlesmultistre...|{"enwiki-20240720...|  done|2024-07-22 13:04:25|
# |    0.8|articlesmultistre...|{"enwiki-20240720...|  done|2024-07-22 13:34:45|
# |    0.8|          babeltable|{"enwiki-20240720...|  done|2024-07-20 10:26:44|
# |    0.8|  categorylinkstable|{"enwiki-20240720...|  done|2024-07-20 08:47:50|
# |    0.8|       categorytable|{"enwiki-20240720...|  done|2024-07-20 09:47:24|
# |    0.8|   changetagdeftable|{"enwiki-20240720...|  done|2024-07-20 10:20:33|
# |    0.8|     changetagstable|{"enwiki-20240720...|  done|2024-07-20 10:18:44|
# |    0.8|  externallinkstable|{"enwiki-20240720...|  done|2024-07-20 09:41:07|
# |    0.8|flaggedpageconfig...|{"enwiki-20240720...|  done|2024-07-20 10:22:08|
# |    0.8|   flaggedpagestable|{"enwiki-20240720...|  done|2024-07-20 10:21:00|
# |    0.8|flaggedrevspromot...|{"enwiki-20240720...|  done|2024-07-20 10:22:44|
# |    0.8|flaggedrevsstatis...|{"enwiki-20240720...|  done|2024-07-20 10:23:15|
# |    0.8|    flaggedrevstable|{"enwiki-20240720...|  done|2024-07-20 10:21:36|
# |    0.8|flaggedrevstracki...|{"enwiki-20240720...|  done|2024-07-20 10:23:44|
# |    0.8|        geotagstable|{"enwiki-20240720...|  done|2024-07-20 10:01:09|
# +-------+--------------------+--------------------+------+-------------------+
# only showing top 20 rows

# %%
df4.orderBy(F.col("updated").desc()).show()
# Out:
# +-------+--------------------+--------------------+------+-------------------+
# |version|          dump_group|               files|status|            updated|
# +-------+--------------------+--------------------+------+-------------------+
# |    0.8|articlesmultistre...|{"enwiki-20240920...|  done|2024-09-28 00:25:33|
# |    0.8|articlesmultistre...|{"enwiki-20240920...|  done|2024-09-28 00:10:01|
# |    0.8|xmlpagelogsdumpre...|{"enwiki-20240920...|  done|2024-09-27 23:49:39|
# |    0.8|     xmlpagelogsdump|{"enwiki-20240920...|  done|2024-09-27 23:46:12|
# |    0.8|metacurrentdumpre...|{"enwiki-20240920...|  done|2024-09-27 23:02:53|
# |    0.8|     metacurrentdump|{"enwiki-20240920...|  done|2024-09-27 20:29:21|
# |    0.8|articlesdumprecom...|{"enwiki-20240920...|  done|2024-09-27 19:16:58|
# |    0.8|        articlesdump|{"enwiki-20240920...|  done|2024-09-27 17:59:51|
# |    0.8|xmlstubsdumprecom...|{"enwiki-20240920...|  done|2024-09-27 16:37:28|
# |    0.8|        xmlstubsdump|{"enwiki-20240920...|  done|2024-09-27 15:26:00|
# |    0.8|abstractsdumpreco...|{"enwiki-20240920...|  done|2024-09-26 08:59:19|
# |    0.8|       abstractsdump|{"enwiki-20240920...|  done|2024-09-26 08:58:23|
# |    0.8|   allpagetitlesdump|{"enwiki-20240920...|  done|2024-09-25 23:02:38|
# |    0.8|      pagetitlesdump|{"enwiki-20240920...|  done|2024-09-25 23:00:41|
# |    0.8|        namespacesv2|{"enwiki-20240920...|  done|2024-09-25 22:59:48|
# |    0.8|          namespaces|{"enwiki-20240920...|  done|2024-09-25 22:59:22|
# |    0.8|          babeltable|{"enwiki-20240920...|  done|2024-09-25 22:58:56|
# |    0.8| wbcentityusagetable|{"enwiki-20240920...|  done|2024-09-25 22:58:22|
# |    0.8|          sitestable|{"enwiki-20240920...|  done|2024-09-25 22:56:28|
# |    0.8|flaggedrevstracki...|{"enwiki-20240920...|  done|2024-09-25 22:56:01|
# +-------+--------------------+--------------------+------+-------------------+
# only showing top 20 rows

# %%
import pendulum
previous_creation_day = pendulum.today(tz="Asia/Ho_Chi_Minh") - pendulum.duration(days=1)
